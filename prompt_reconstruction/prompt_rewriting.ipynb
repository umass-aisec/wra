# %%
from openai import OpenAI
import os
import datetime
from urllib.parse import urlparse
import re

os.environ["OPENAI_API_KEY"] = "your_openai_key_here"
os.environ["GEMINI_API_KEY"] = "your_gemini_key_here"
os.environ["GOOGLE_API_KEY"] = "your_google_key_here"
os.environ["DEEPSEEK_API_KEY"] = "your_deepseek_key_here"


client = OpenAI(timeout=3600)

# %%
suggested_rewriting_prompt = """
You will be given a research task by a user. Your job is to produce a set of instructions for a researcher that will complete the task. Do NOT complete the task yourself, just provide instructions on how to complete it.

GUIDELINES:
1. **Maximize Specificity and Detail**
- Include all known user preferences and explicitly list key attributes or dimensions to consider.
- It is of utmost importance that all details from the user are included in the instructions.

2. **Fill in Unstated But Necessary Dimensions as Open-Ended**
- If certain attributes are essential for a meaningful output but the user has not provided them, explicitly state that they are open-ended or default to no specific constraint.

3. **Avoid Unwarranted Assumptions**
- If the user has not provided a particular detail, do not invent one.
- Instead, state the lack of specification and guide the researcher to treat it as flexible or accept all possible options.

4. **Use the First Person**
- Phrase the request from the perspective of the user.

5. **Tables**
- If you determine that including a table will help illustrate, organize, or enhance the information in the research output, you must explicitly request that the researcher provide them.
Examples:
- Product Comparison (Consumer): When comparing different smartphone models, request a table listing each model's features, price, and consumer ratings side-by-side.
- Project Tracking (Work): When outlining project deliverables, create a table showing tasks, deadlines, responsible team members, and status updates.
- Budget Planning (Consumer): When creating a personal or household budget, request a table detailing income sources, monthly expenses, and savings goals.
Competitor Analysis (Work): When evaluating competitor products, request a table with key metrics, such as market share, pricing, and main differentiators.

6. **Headers and Formatting**
- You should include the expected output format in the prompt.
- If the user is asking for content that would be best returned in a structured format (e.g. a report, plan, etc.), ask the researcher to format as a report with the appropriate headers and formatting that ensures clarity and structure.

7. **Language**
- If the user input is in a language other than English, tell the researcher to respond in this language, unless the user query explicitly asks for the response in a different language.

8. **Sources**
- If specific sources should be prioritized, specify them in the prompt.
- For product and travel research, prefer linking directly to official or primary websites (e.g., official brand sites, manufacturer pages, or reputable e-commerce platforms like Amazon for user reviews) rather than aggregator sites or SEO-heavy blogs.
- For academic or scientific queries, prefer linking directly to the original paper or official journal publication rather than survey papers or secondary summaries.
- If the query is in a specific language, prioritize sources published in that language.
"""

import os
import re
import json

# File paths to your parsed prompt files
parsed_files = [
    "FEDWEB13.txt",
    "SESSION2014.txt"
]

# Helper to extract "Prompt N: ..." blocks
def extract_prompts(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()
    return re.findall(r"Prompt \d+:\s*(.*?)\n\n", content, re.DOTALL)

# Output file for OpenAI Batch API
output_path = "my_batch_requests.jsonl"

# # Function to rewrite prompts via OpenAI API
# def rewrite_prompt(prompt, client, model="gpt-4.1-2025-04-14"):
#     response = client.responses.create(
#         instructions=suggested_rewriting_prompt,
#         model="gpt-4.1-2025-04-14",
#         input=prompt
#     )
#     return response.output[0].content[0].text
    

# Build the batch JSONL
with open(output_path, "w", encoding="utf-8") as out_f:
    task_id = 1
    for file_path in parsed_files:
        prompts = extract_prompts(file_path)
        for prompt in prompts:
            request = {
                "custom_id": f"task-{task_id}",
                "method": "POST",
                "url": "/v1/responses",
                "body": {
                    "instructions": suggested_rewriting_prompt,
                    "input": prompt.strip(),
                    "model": "gpt-4.1-2025-04-14",  # Or gpt-4.0 / gpt-4.1 depending on support
                }
            }
            out_f.write(json.dumps(request) + "\n")
            task_id += 1

print(f"✅ Created batch request file: {output_path}")

# %%
from openai import OpenAI
client = OpenAI()

batch_input_file = client.files.create(
    file=open("my_batch_requests.jsonl", "rb"),
    purpose="batch"
)

print(batch_input_file)

batch_input_file_id = batch_input_file.id
client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/responses",
    completion_window="24h",
    metadata={
        "description": "rewriting prompts"
    }
)
# Out:
# FileObject(id='file-UoNfjUD8WB2Q9FZsqg55zb', bytes=378514, created_at=1752529824, filename='my_batch_requests.jsonl', object='file', purpose='batch', status='processed', expires_at=None, status_details=None)
# Batch(id='batch_68757ba094588190aa9b27334359f611', completion_window='24h', created_at=1752529824, endpoint='/v1/responses', input_file_id='file-UoNfjUD8WB2Q9FZsqg55zb', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1752616224, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'rewriting prompts'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
file_response = client.files.content("file-68757ba094588190aa9b27334359f611")
print(file_response.text)

# %%
import os
import re
import json

# File paths to your parsed prompt files
parsed_files = [
    "FEDWEB13.txt",
    "SESSION2014.txt"
]

# Helper to extract "Prompt N: ..." blocks
def extract_prompts(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()
    return re.findall(r"Prompt \d+:\s*(.*?)\n\n", content, re.DOTALL)

# Output file for OpenAI Batch API
output_path = "my_batch_requests.jsonl"

# # Function to rewrite prompts via OpenAI API
# def rewrite_prompt(prompt, client, model="gpt-4.1-2025-04-14"):
#     response = client.responses.create(
#         instructions=suggested_rewriting_prompt,
#         model="gpt-4.1-2025-04-14",
#         input=prompt
#     )
#     return response.output[0].content[0].text
    

# Build the batch JSONL
with open(output_path, "w", encoding="utf-8") as out_f:
    task_id = 1
    for file_path in parsed_files:
        prompts = extract_prompts(file_path)
        for prompt in prompts:
            request = {
                "custom_id": f"task-{task_id}",
                "method": "POST",
                "url": "/v1/responses",
                "body": {
                    "instructions": suggested_rewriting_prompt,
                    "input": prompt.strip(),
                    "model": "gpt-4.1-2025-04-14",  # Or gpt-4.0 / gpt-4.1 depending on support
                }
            }
            out_f.write(json.dumps(request) + "\n")
            task_id += 1

print(f"✅ Created batch request file: {output_path}")

# %%
suggested_rewriting_prompt = """
You will be given a research task by a user. Your job is to produce a set of instructions for a researcher that will complete the task. Do NOT complete the task yourself, just provide instructions on how to complete it.

GUIDELINES:
1. **Maximize Specificity and Detail**
- Include all known user preferences and explicitly list key attributes or dimensions to consider.
- It is of utmost importance that all details from the user are included in the instructions.

2. **Fill in Unstated But Necessary Dimensions as Open-Ended**
- If certain attributes are essential for a meaningful output but the user has not provided them, explicitly state that they are open-ended or default to no specific constraint.

3. **Avoid Unwarranted Assumptions**
- If the user has not provided a particular detail, do not invent one.
- Instead, state the lack of specification and guide the researcher to treat it as flexible or accept all possible options.

4. **Use the First Person**
- Phrase the request from the perspective of the user.

5. **Tables**
- If you determine that including a table will help illustrate, organize, or enhance the information in the research output, you must explicitly request that the researcher provide them.
Examples:
- Product Comparison (Consumer): When comparing different smartphone models, request a table listing each model's features, price, and consumer ratings side-by-side.
- Project Tracking (Work): When outlining project deliverables, create a table showing tasks, deadlines, responsible team members, and status updates.
- Budget Planning (Consumer): When creating a personal or household budget, request a table detailing income sources, monthly expenses, and savings goals.
Competitor Analysis (Work): When evaluating competitor products, request a table with key metrics, such as market share, pricing, and main differentiators.

6. **Headers and Formatting**
- You should include the expected output format in the prompt.
- If the user is asking for content that would be best returned in a structured format (e.g. a report, plan, etc.), ask the researcher to format as a report with the appropriate headers and formatting that ensures clarity and structure.

7. **Language**
- If the user input is in a language other than English, tell the researcher to respond in this language, unless the user query explicitly asks for the response in a different language.

8. **Sources**
- If specific sources should be prioritized, specify them in the prompt.
- For product and travel research, prefer linking directly to official or primary websites (e.g., official brand sites, manufacturer pages, or reputable e-commerce platforms like Amazon for user reviews) rather than aggregator sites or SEO-heavy blogs.
- For academic or scientific queries, prefer linking directly to the original paper or official journal publication rather than survey papers or secondary summaries.
- If the query is in a specific language, prioritize sources published in that language.
"""

# %%
# Paths to parsed prompt files
parsed_files = [
    "DD2016.txt",
    "FEDWEB13.txt",
    "SESSSION2014.txt"
]

# Function to extract prompts from a file
def extract_prompts(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()
    return re.findall(r"Prompt \d+:\s*(.*?)\n\n", content, re.DOTALL)

# Function to rewrite prompts via OpenAI API
def rewrite_prompt(prompt, client, model="gpt-4.1-2025-04-14"):
    response = client.responses.create(
        instructions=suggested_rewriting_prompt,
        model="gpt-4.1-2025-04-14",
        input=prompt
    )
    return response.output[0].content[0].text

# %%
# Initialize OpenAI client
client = OpenAI()  # or openai.Client(api_key="your-key")

# Output directory
os.makedirs("rewritten_prompts", exist_ok=True)

# Process each file
for file_path in parsed_files:
    prompts = extract_prompts(file_path)
    rewritten = []

    print(f"Rewriting prompts from {file_path}...")

    for i, prompt in enumerate(prompts, start=45):
        rewritten_text = rewrite_prompt(prompt, client)
        rewritten.append(f"Prompt {i}: {rewritten_text}\n")

    # Save to output file
    out_path = os.path.join("rewritten_prompts", os.path.basename(file_path).replace(".txt", ".rewritten2.txt"))
    with open(out_path, "w", encoding="utf-8") as f:
        f.writelines("\n".join(rewritten))

    print(f"✔ Saved rewritten prompts to {out_path}")

# %%
import re

def renumber_prompts(input_path, output_path):
    # Read input file
    with open(input_path, "r", encoding="utf-8") as f:
        content = f.read()

    # Find all prompt blocks
    prompts = re.findall(r"Prompt\s+\d+:\s*(.*?)(?=(?:Prompt\s+\d+:|$))", content, re.DOTALL)

    # Reconstruct content with new numbering
    renumbered = "\n\n".join([f"Prompt {i+1}: {p.strip()}" for i, p in enumerate(prompts)])

    # Save to output file
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(renumbered)

    print(f"✅ Renumbered prompts saved to: {output_path}")

# Example usage
renumber_prompts("rewritten_prompts/DD2016.rewritten2.txt", "rewritten_prompts/DD2016.rewritten.txt")
# Out:
# ✅ Renumbered prompts saved to: rewritten_prompts/DD2016.rewritten.txt

# %%
import json

def extract_outputs_from_jsonl(input_path, output_path):
    extracted_texts = []

    # Read each JSON line
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            try:
                data = json.loads(line)

                # Extract assistant message content
                content_blocks = data["response"]["body"]["output"][0]["content"]

                # Concatenate all blocks of type 'output_text'
                output_text = "\n".join(
                    block["text"] for block in content_blocks if block["type"] == "output_text"
                )

                extracted_texts.append(output_text.strip())

            except Exception as e:
                extracted_texts.append(f"[ERROR parsing line]: {e}")

    # Write to output file
    with open(output_path, "w", encoding="utf-8") as out_f:
        for i, text in enumerate(extracted_texts, start=1):
            out_f.write(f"Prompt {i}:\n{text}\n\n")

    print(f"✅ Extracted {len(extracted_texts)} outputs to: {output_path}")

# === Example Usage ===
input_file = "rewritten_prompts/SESSION14.rewritten.txt"
output_file = "rewritten_prompts/SESSION14.rewritten_outputs_extracted.txt"
extract_outputs_from_jsonl(input_file, output_file)
# Out:
# ✅ Extracted 60 outputs to: rewritten_prompts/SESSION14.rewritten_outputs_extracted.txt

# %%
response.model_dump().get("output", [])
# Out:
# [{'id': 'rs_687fc93d8684819182495abf2a04ceaa0fb66a0de26da257',
#   'summary': [{'text': "**Exploring Swahili cuisine**\n\nThe user is asking for a detailed report on traditional Swahili dishes, which sounds fascinating! I think I should collect information on various recipes, their cultural significance, and cooking methods. It’ll be important to organize this data in a clear way so it's easy for the user to follow. I’m curious to see what unique flavors and ingredients are typically used in these dishes, and how they reflect the rich culture of the Swahili coast!",
#     'type': 'summary_text'},
#    {'text': "**Crafting a Swahili cuisine report**\n\nThe user wants to learn about traditional Swahili dishes to surprise a friend from Kenya, and they've given clear instructions. I need to focus specifically on Swahili home cooking, creating a structured report that includes at least five traditional dishes, each with a brief description and resource link. Including pictures or videos would be beneficial, even if they haven't requested to embed them. The report will have headings like Overview of Swahili Cuisine, Popular Dishes, and Cooking Resources.",
#     'type': 'summary_text'},
#    {'text': "**Researching traditional Swahili dishes**\n\nI’m gathering information on traditional Swahili dishes like mkate wa sinia, mahakari, and kuku paka, focusing on their recipes and how to cook them. The goal is to find reputable sources that offer clear instructions from home cooks, including detailed descriptions and links. I'll create a structured report with a table listing at least five dishes and their significance. It's crucial to ensure the resources are genuine and not just SEO-heavy aggregators. Let’s see what I can uncover!",
#     'type': 'summary_text'},
#    {'text': '**Structuring the Swahili cuisine report**\n\nI’m planning the report to give an overview of Swahili cuisine, emphasizing key characteristics like coconut, spices, and coastal flavors, along with influences from Arab and Indian cultures. The overview will cover the geographical areas of coastal Kenya and Tanzania while introducing significant dishes. The section on popular dishes will describe each dish briefly, while a separate table in the cooking instructions section will summarize their names, descriptions, and cooking links. This organization should provide clarity and depth for the user’s needs!',
#     'type': 'summary_text'},
#    {'text': '**Identifying recipe sources for Swahili dishes**\n\nI’m considering that bajias or samosas might still be popular home-cooked options, especially for snacks or iftar. I need to find at least five solid recipes with clear instructions, ideally accompanied by pictures or videos for better guidance. Some potential sources could include well-known food blogs like "Nairobi Kitchen" and "Kaluhi’s Kitchen," though they might lean toward modern interpretations. I’ll look for specifically focused "Swahili recipe blogs" to gather more authentic recipes.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9668b4881919fe247880800a8fb0fb66a0de26da257',
#   'action': {'query': 'Swahili home cooking recipes traditional',
#    'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc967f94c819181a1ffdea09a40280fb66a0de26da257',
#   'summary': [{'text': '**Evaluating Swahili food sources**\n\nI\'m looking at the results related to Swahili food. The first two seem relevant, with one from a site called "All Recipes • Swahili Food by Vanessa," which could possibly be a personal blog. I\'ll check it out to see what it offers. The second result points to "Best Kenyan Swahili dishes" on Tuko.co.ke, a known news aggregator. While it may not be the most authoritative source, it might list some interesting dishes. I\'m curious to see.',
#     'type': 'summary_text'},
#    {'text': '**Analyzing recipe sources**\n\nI\'m evaluating various sources for Swahili recipes. Cookpad appears user-generated and may feature multiple home recipes. However, it lacks curation and often provides minimal context, which is less than ideal. There\'s also a potential blog or book titled "WAPISHI - Sensory Swahili," but it isn\'t clear from the snippet. Another site focuses on language rather than recipes and Kaluhi\'s Kitchen may have some relevant posts on Swahili dishes. Lastly, there\'s a blog called "superchicken.ca" that might summarize Swahili cuisine, but I\'m uncertain about its reliability.',
#     'type': 'summary_text'},
#    {'text': '**Finding Swahili recipes**\n\nI’m aiming to locate web pages that focus specifically on Swahili home cooking, ideally actual recipe pages or listings with recipes. Some popular dishes to consider include Pilau, Biryani, Wali wa Nazi (coconut rice), and various coconut-based dishes like Samaki wa Kupaka (fish) and Kuku Paka (chicken). I’ll also look into Mandazi and Kaimati. Additionally, I wonder if there’s a unique term for a Swahili chicken curry. I’ll check the first result for confirmation on dish listings.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc97122108191b26f1b40140a9f590fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc972c4f4819182dca15ddbef91360fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc972c7f08191ac29edc237e8811d0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': '###',
#    'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc973f4f88191bde34f4a967ae2080fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc973fd208191b4deb21de77045f20fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': None},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9744bb08191bb41bc6852d93a150fb66a0de26da257',
#   'summary': [{'text': "**Reviewing Swahili dishes**\n\nI'm looking at a list from Tuko that highlights several traditional Swahili dishes, complete with images. It includes seven dishes: Kaimati, Swahili Pilau, Mahamri, Viazi vya rojo (which seems like a potato stew), Wali wa nazi (coconut rice), Bhajia (fritters), and Nduma za nazi (taro in coconut). Some of these, like Kaimati (dessert dumplings) and Mahamri (donuts), I didn’t initially recall. It’s interesting to explore these recipes!",
#     'type': 'summary_text'},
#    {'text': '**Exploring Swahili street food**\n\nI’m considering "viazi vya rojo," which is a popular street food in Zanzibar featuring boiled potatoes coated in a red sauce. Other dishes included in Tuko\'s list are Wali wa nazi (coconut rice), Bhajia (fried potatoes), and Nduma za nazi (arrowroots in coconut milk). While Tuko is a good starting point, it\'s important to double-check its accuracy as it may not be an original source. I’ll look for other sites, especially for recipes on Kaimati and Pilau. Aroma of Zanzibar could be a useful reference too!',
#     'type': 'summary_text'},
#    {'text': '**Determining Swahili dishes to include**\n\nI want to find a good Swahili style Pilau recipe, ideally from a reputable site. The Tuko list is helpful, but could lack detail. Interestingly, it didn’t mention Biryani, which is a key dish in Mombasa. Other dishes like Samaki wa kupaka and Kuku wa kupaka are also staples but were omitted. I’m considering a variety of dishes to meet the requirement of listing at least five, like Pilau, Biryani, Wali wa Nazi, Kuku wa kupaka, and Samaki wa kupaka along with desserts like Kaimati. A table format could work nicely for clarity!',
#     'type': 'summary_text'},
#    {'text': '**Organizing references and citations**\n\nI need to compile references for the project. The user mentioned they want all sources linked, so I might create a section at the end with clickable links and descriptions. Perhaps following a style like: "[Site - Recipe](link)." I should also include embedded citations for facts in the text. Gathering authoritative sources for Swahili cuisine will be key. For each dish, I want to mention its significance, like Pilau being a celebratory dish, and include citations for its prevalence or special occasions. It\'s important I get reputable references, especially for popular dishes.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9881d2c819190fddea80cc5530e0fb66a0de26da257',
#   'action': {'query': 'Swahili pilau recipe Kenya', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9891e8c8191827de24f9cebd6750fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9899af08191b8fefa0431e599ae0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc98c6e048191b2dc071c859e39cb0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc98c738c8191bce9621dc4aeded30fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': '## what is Pilau',
#    'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc98cd1288191a638257b086191280fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc98e206c819188a098b2ce9c8dbe0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'Samaki wa Kupaka',
#    'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc98e94c88191be0a4f7cb4febf3e0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc98f6054819187fe6563533353a80fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc990024081919b5e35b327e5c3860fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9908e8c81918fff5696107796de0fb66a0de26da257',
#   'action': {'query': 'We Eat At Last Samaki wa Kupaka', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc992049c8191a10be252270774b60fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc99277ac8191a5052ccfa311a6120fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/samaki-wa-kupaka-grilled-fish-in-coconut-sauce/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9938ba4819187602eae154a5c380fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc993909c8191ab2fcf192c84f9a00fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'It is a popular East African dish',
#    'url': 'https://weeatatlast.com/samaki-wa-kupaka-grilled-fish-in-coconut-sauce/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc993f4dc819198adad27ffb549dd0fb66a0de26da257',
#   'summary': [{'text': '**Researching coastal dishes**\n\nSamaki wa Kupaka is indeed popular in coastal areas like Mombasa and Lamu, as well as in Zanzibar and Tanzania. I’ll note that in the description. We should also attach a recipe link, which is hinting at weeatlast.com. I\'ll look for information about Pilau and Kuku Paka from the same source. If WeEatAtLast has these dishes, that would be perfect. Additionally, I need to search for "biryani" there to explore more options.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc99969a88191aac2406d2f8c099d0fb66a0de26da257',
#   'action': {'query': 'site:weeatatlast.com biryani', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc99a42f481919172b71387c5bb6b0fb66a0de26da257',
#   'summary': [{'text': '**Exploring menu options**\n\nI\'m checking if "We Eat At Last" has biryani, but the search isn’t confirming that. I should explore whether they offer Mandazi or Mahamri instead! I wonder if those dishes fit in the category of African cuisine? It’s an interesting challenge to find out what they specialize in. I\'ll keep looking for more relevant options on their menu to help the user find something delicious!',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc99c3c588191be40bac936e3bcd40fb66a0de26da257',
#   'action': {'query': 'site:weeatatlast.com mandazi', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc99d05348191a1044fae219e49c70fb66a0de26da257',
#   'summary': [{'text': '**Searching for Mandazi recipes**\n\nI can\'t find a direct link for Mandazi from WeEatAtLast, so I\'m looking for other sources. One option could be "Aroma of Zanzibar," which I believe is a popular YouTube channel that may also have a blog featuring recipes. "Xawaash" might be useful, but I\'m unsure about the Swahili content. Then there are "Pikachakula" and "allkenyanrecipes.com" to consider. I also want to check out "Swahili Food by Vanessa," as it appears to have multiple recipe categories.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9a154188191bccbf69bce9af23e0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://swahilifood.com/all-recipes/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9a1fd7081918371554fed8fc7cc0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9a24a348191b3c08d57c76b0a410fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': 'https://swahilifood.com/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9a2f3c08191bca67c6f87016c100fb66a0de26da257',
#   'summary': [{'text': '**Exploring site categories**\n\nIt seems the site looks modern and dynamic, with categories we can click through. I\'m not sure if it\'s actually showing any recipes yet. Let\'s investigate by clicking on options like "Beef" or "Mains" to see if we can find any recipes listed there. I’m curious to discover what delicious ideas might be hidden within those categories!',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9a4a4d4819197aef3992f17d7060fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://swahilifood.com/category/mains/beef/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9a4f17c8191a9fde77f9537e9420fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9a53854819184ed10084c5f493b0fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': None},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9a571548191b03c23d3a016b1070fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9a75e508191b0912de756994c9e0fb66a0de26da257',
#   'action': {'query': 'Swahili Food by Vanessa pilau', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9a8dba48191ae30e8af7ac56f3b0fb66a0de26da257',
#   'summary': [{'text': '**Exploring Swahili recipes**\n\nIt looks like the search results for "Swahili Food by Vanessa" mention a dish like Swahili Pilau Spiced Chicken & Jollof Rice, but I\'m wondering if it’s a combined recipe with a twist rather than a traditional pilau. I might not rely too much on that site since navigation seems tricky. Instead, I could check other sources like the "We Eat At Last" blog, which covers Pilau and Samaki wa Kupaka, and maybe search specifically for a "Kuku Paka" recipe.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9ac5f4c8191820d0f0c569c7e640fb66a0de26da257',
#   'action': {'query': 'Kuku Paka Swahili recipe', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9acd42c8191a70fd82928ea308f0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9ad1e708191a50c19ee7cd938960fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9adc5c48191a83d9f91a40b1d080fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9adec0481919e07762cbd66e93d0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'In Kenya, it is particularly popular',
#    'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9ae6d808191b192d36939ba02970fb66a0de26da257',
#   'summary': [{'text': '**Exploring Kuku Paka and Related Dishes**\n\nKuku Paka, or coconut chicken, is a Swahili dish defined as chicken in coconut sauce, mainly enjoyed in East Africa, particularly in Mombasa and Lamu. It has a blend of Indian, Arabic, and African roots. The site "We Eat At Last" seems to feature dishes linked to Kenyan cuisine, including Pilau, Samaki wa Kupaka, Kuku Paka, and possibly Wali wa Nazi, which refers to Swahili Coconut Rice. It\'s fascinating to see these cultural intersections!',
#     'type': 'summary_text'},
#    {'text': '**Investigating Swahili Coconut Rice**\n\nIt looks like "We Eat At Last" definitely has a recipe for "Swahili Coconut Rice," mentioned alongside other dishes like cassava fufu and egusi soup. The snippet suggests it’s likely included on the Kuku Paka page. While exploring the page, I find mentions of making Kuku Paka and other recipes learned from family, which adds a personal touch. I’ll keep an eye out for any direct references to "coconut rice" for confirmation.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9b583e88191abafc7a8d3b5b6ea0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'Swahili Coconut Rice',
#    'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9b58cf081919d2fed57638ef76e0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9b5edcc819196c8461aafd3713e0fb66a0de26da257',
#   'action': {'query': '"Swahili Coconut Rice" "We Eat At Last"',
#    'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9b6c2c08191b4f0217d93dfd8360fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9b72a0881919c70bc554d81ed1b0fb66a0de26da257',
#   'action': {'query': 'Swahili Coconut Rice weeatatlast', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9b913a0819194b68c52695082410fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9b9ba0c81918defecc5103ae0bd0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/swahili-coconut-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9bce5188191abd89c8cf74568a40fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9bce9908191be2ad5d15bfc34e30fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'also known as wali wa nazi',
#    'url': 'https://weeatatlast.com/swahili-coconut-rice/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9bd5c30819180c70bef4195f13d0fb66a0de26da257',
#   'summary': [{'text': '**Summarizing Swahili cuisine**\n\nI’m gathering some great information about Wali wa Nazi, which is Swahili coconut rice popular in coastal Kenya, especially Mombasa. This dish highlights influences through coconut usage. I might mention it in the overview or briefly summarize its context. WeEatAtLast seems like a credible source with relevant content, including notable dishes like Kuku Paka, Samaki, and Pilau. It may not go into snacks or sweets much, but it’s a good base for further exploration.',
#     'type': 'summary_text'},
#    {'text': '**Considering popular desserts**\n\nI’m looking into including Mandazi or Mahamri, which are iconic East African snacks. Mahamri is a Swahili variant of Mandazi, often made with coconut milk and cardamom, popular along the coast. While "Mandazi" is a broader term that could lack the coastal nuance, I might use "Mahamri (Swahili Mandazi)" to acknowledge both. I’ll search for a recipe from Kaluhi\'s Kitchen, or possibly "A Taste of Mombasa," which likely has a local perspective.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9c4e2088191ae7387eb1427da710fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://theswahilijourney.blogspot.com/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9c78ffc8191961d0bc75db476530fb66a0de26da257',
#   'summary': [{'text': '**Considering a blog resource**\n\nThe blog at "swahilijourney.blogspot.com" seems like an older site by someone likely from Mombasa, given the username "Binti wa Mombasa," which translates to "daughter of Mombasa." It includes some personal and authentic content, including a recipe for "Viazi Vya Nazi - Potatoes in Coconut Milk." Although it’s from 2011, it aligns with the user’s request for resources from home cooks focusing on authentic Swahili cuisine. I think it’s worth including it as a link for authenticity.',
#     'type': 'summary_text'},
#    {'text': '**Searching for popular Swahili recipes**\n\nI think I should focus on more widely known Swahili dishes, since authenticity is important but familiarity could engage the user’s friend. It would make sense to find updated recipes for dishes like Mandazi and Kaimati, which are likely more recognizable. Since the user wants to surprise a friend who probably misses authentic coastal fare, dishes like Pilau and Biryani might be good choices. \n\nI\'ll gather references for each dish, including Pilau, Mombasa Biryani, Wali wa Nazi, Kuku Paka, Samaki wa Kupaka, Mandazi, and Kaimati. I’ll look for reliable sources, especially for Kaimati, potentially from "Aroma of Zanzibar."',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9ce0f588191a00e042be0eed61a0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9d6451881918097283fbd2120c20fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9d64b2c81918aa9a603849e428c0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': '## Real exotic taste with mahamri',
#    'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9d656688191a2889f7a459ed5450fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9d7d4f88191aa5695a9388ac6d50fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9dfbd988191af949043ce1457630fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9dfc1d08191a5cf5f8e91f8b1c90fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': '## Addictive little viazi karai',
#    'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9e0236481919c53a8384f8c79d30fb66a0de26da257',
#   'summary': [{'text': "**Summarizing Trip101 food article**\n\nThe Trip101 article discusses several enticing dishes. It introduces Mahamri and Mandazi, providing context rather than a recipe. It also covers Barazi, a pigeon peas coconut stew, and Maharagwe, which features red beans in coconut. Additionally, it mentions Viazi Karai, fried potatoes served with tamarind sauce, and spicy Samosas paired with lemon. I wonder if the next dishes will include Kaimati or Vitumbua, both popular options. It's interesting to explore this culinary landscape!",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9e2a21881919b6adc209fbe5adb0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'kaimati',
#    'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9e2ef3c8191a0ed5ecc35b1a6b80fb66a0de26da257',
#   'summary': [{'text': '**Identifying snack details**\n\nOkay, I\'ve got details about Kaimati, which comes in two types: one glazed and one soaked in syrup. "Njugu paak," the peanut brittle candy, is also mentioned and described as peanuts cooked in sugary brittle. The article from Trip101 gives a cultural overview of these snacks, but it lacks actual recipe instructions. I need to find links to cooking instructions from blogs or recipe sites, but it\'s likely that such articles won’t include those.',
#     'type': 'summary_text'},
#    {'text': '**Finding specific recipes**\n\nI want to look for specific recipe pages for Mahamri or Mandazi, Kaimati, and possibly Biryani, even though it\'s not mentioned in Tuko. Biryani is commonly known as a Swahili dish. I might also consider "Maharagwe ya nazi" or "Mbaazi za nazi" if I have space. I plan to list at least five options for variety: iconic rice dishes like Pilau and Biryani, breakfast snacks like Mandazi or Mahamri, the curry dish Kuku Paka, and perhaps a vegetarian side. Fish dishes might be good to include if my friend enjoys fish.',
#     'type': 'summary_text'},
#    {'text': '**Selecting dishes for variety**\n\nI think it’s a good idea to include a diverse range of dishes. We can feature Pilau (often called "Swahili Pilau Rice" for celebrations), Kuku Paka (chicken in coconut), Samaki wa Kupaka (fish), and Wali wa Nazi (coconut rice). That gives us four dishes. We should add either Biryani or Mandazi, definitely including one sweet like Mahamri, which pairs well with chai. I want to find a recipe link for Mahamri, perhaps searching for "How to make Mahamri."',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9ec99d081919684a2e1439122ef0fb66a0de26da257',
#   'action': {'query': 'Mahamri recipe Swahili', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9f2a60c8191b3347848452626ad0fb66a0de26da257',
#   'summary': [{'text': "**Evaluating recipe sources**\n\nI'm checking out the results for Mahamri recipes. The first three are from Cookpad, which might not be the most authoritative resources we're looking for. However, the ToasterDing site has an authentic-sounding recipe that could be promising, especially if the quality is high. They emphasize using cardamom and coconut milk, which is intriguing. Lastly, We Eat At Last seems to have a Mahamri page too, particularly as they've featured other related content. Let's explore that one.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9f54ef4819193ff40572d3df2540fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://weeatatlast.com/mahamri-recipe/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9f6235c81919a55fe3785f85b2d0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9f62d708191a6eab049ff51da3b0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'Mahamri is a triangular-shaped',
#    'url': 'https://weeatatlast.com/mahamri-recipe/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9f6880c8191aa75a7b905540d1b0fb66a0de26da257',
#   'summary': [{'text': "**Clarifying food descriptions**\n\nI'm focusing on describing Mahamri, a triangular donut that includes coconut milk and is popular for breakfast in coastal Kenya, specifically Mombasa. It pairs well with chai or pigeon peas. I’ll confirm the differences between Mahamri and Mandazi, as it's clear Mandazi is a broader term while Mahamri is the specific coastal variety with distinct flavors thanks to ingredients like yeast and cardamom. Now, I’ll look for a biryani recipe from a trusted source.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9f911208191b7b8006bdb89c5dd0fb66a0de26da257',
#   'action': {'query': 'Swahili biryani recipe Mombasa', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fc9fa6c1c81919886811f519581560fb66a0de26da257',
#   'summary': [{'text': "**Exploring Swahili dishes**\n\nI'm looking at various sources for Swahili dishes. Magical Kenya might offer a tourism perspective on local cuisine, though it may lack recipes. HelloMombasa.com seems promising with an article on popular street foods. It could provide insights into what's loved in that region. Thefood.zone mentions Mombasa Biryani, which looks like a recipe site, but I wonder about its reliability. I think I’ll start with Magical Kenya since it’s an official tourism site for potentially credible information.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fc9fc97c08191a4ff679911680d550fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://magicalkenya.com/map/swahili-dishes/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca013fe88191a04206ee8a056d5c0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca022820819196587ece832868c60fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca181e888191b5db20dd5eedee680fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca18c74881919c06eafca467eb3b0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'Crown Jewel of Swahili Local Dishes',
#    'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca18cf108191aecfe851f4ef837a0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca18d7cc8191ab5fde8b7ffb50330fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': None},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca1914c8819191a01cf1ecdcbaab0fb66a0de26da257',
#   'summary': [{'text': '**Reviewing dish placements**\n\nI\'m thinking about the placement of dishes in the list. It looks like Samaki wa Kupaka should rank closer to #5 since the Table of Contents describes it as the "Crown Jewel of Swahili Local Dishes." That snippet really emphasizes its significance. I might search for "## Samaki" or "Fish in Coconut" to find more context around its description. This could help confirm its proper placement in the list!',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca1b6b58819192d4675b48e75b2c0fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': '## Samaki wa Kupaka',
#    'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca1b75d88191bfeb8598abebf09e0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca1b7df4819193a521e54179a4130fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': None},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca1bd02c8191aa70e01acbcd94c00fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca1c1b908191bf5057cdba3ab0400fb66a0de26da257',
#   'action': {'type': 'open_page', 'url': None},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca1c5d04819195d27001d00b8f660fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca1ca70c8191989cc4cba72e31430fb66a0de26da257',
#   'action': {'query': '"Crown Jewel of Swahili Local Dishes"',
#    'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca1d8f7c819184482d8cd39d27560fb66a0de26da257',
#   'summary': [{'text': "**Exploring Content Connections**\n\nI'm looking into the possibility that Kenyalad and wanderlusttrails have similar content to HelloMombasa, as the latter link features wanderlusttrails. They might be part of the same content network or brand. I think we have enough information from HelloMombasa to include in the report, especially the biryani description, noting its unique ingredients like tomatoes, cinnamon, and cardamom. However, I should keep the report concise while ensuring it’s data-driven and informative as requested.",
#     'type': 'summary_text'},
#    {'text': "**Refining Dish Descriptions**\n\nI’m planning to include specifics in the dish descriptions, like spices and accompaniments such as tamarind chutney and kachumbari, to enhance the authenticity. However, I want to keep each entry concise, focusing on one key fact about each dish's significance or flavor. For example, highlighting that Kaimati is a popular snack during Ramadan might be valuable, especially since the user wants to learn to cook. I’m considering including around seven dishes, which feels manageable and informative.",
#     'type': 'summary_text'},
#    {'text': "**Gathering Dish Descriptions**\n\nI'm collecting references for each dish now. For **Pilau**, it’s noted as popular in East Africa, especially Kenya and Tanzania. It's influenced by Indian and Arab cuisines, typically spiced with cloves, cardamom, and sometimes coconut milk. I might mention that Kenyan pilau is darker due to caramelized onions. \n\nFor **Biryani**, HelloMombasa has an excellent description highlighting its rich flavors, layers of basmati rice, and meat, along with spices that set it apart from Indian versions. I’ll also look for a recipe link for added resources.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca2588cc8191be5cf50f464633420fb66a0de26da257',
#   'action': {'query': 'Mombasa biryani recipe blog', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca25ffe88191a690dc5d5d06766f0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca2652bc8191a74ba91e88e89e630fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://thefood.zone/recipe/mombasa-biryani'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca2e3c7481918a52735d12b55de60fb66a0de26da257',
#   'summary': [{'text': '**Evaluating recipe sources**\n\nTheFood.zone has a well-organized recipe, presumably from user contributions or a blog, which could be useful as a link. Its brief description defines Mombasa Biryani as a flavorful rice dish with tender meat and spices, making it suitable for citing. However, HelloMombasa offers a more intriguing take that highlights unique ingredients like tomatoes. For a concise report, I might choose the simpler description of biryani as a signature coastal dish, while MagicalKenya also confirms its authenticity without specifics.',
#     'type': 'summary_text'},
#    {'text': '**Considering recipe sourcing**\n\nQuoting HelloMombasa about biryani seems appropriate, as it describes it as a coastal culinary fusion with basmati rice, meat, and spices, emphasizing how Mombasa-style is wetter and more aromatic than its Indian counterpart. We could paraphrase or shorten this description while still citing it.\n\nFor Kuku Paka, using WeEatAtLast is ideal since they give a clear definition, while MagicalKenya references coconut curries without naming it specifically. For Samaki wa Kupaka, WeEatAtLast offers a solid definition, and I may want to check HelloMombasa for additional praise it might provide.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca3556388191a56ac77d32548d050fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'coconut',
#    'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca4500748191a5aebd724a2183730fb66a0de26da257',
#   'summary': [{'text': "**Refining the Samaki description**\n\nI'm looking at the content for describing Samaki wa kupaka, a highlight of Swahili cuisine. It’s essentially grilled fish like snapper or tilapia, coated in a rich coconut sauce flavored with turmeric, garlic, chili, and lime. The preparation involves grilling the fish, coating it, and grilling it again for a smoky finish. This dish illustrates cultural exchange through coastal trade that introduced various ingredients to East Africa. While it’s quite detailed, we might simplify it without losing its essence.",
#     'type': 'summary_text'},
#    {'text': '**Streamlining dish descriptions**\n\nI should highlight the unique techniques, like marinade and charcoal grilling, for Samaki wa Kupaka. I think we can simplify it to: "Samaki wa Kupaka, meaning \'fish that is slathered,\' features grilled snapper or tilapia in a coconut sauce seasoned with turmeric, garlic, chili, and lime. This dish is a popular signature of Swahili cuisine, especially at coastal locations like Zanzibar." \n\nFor Wali wa Nazi, I\'ll mention its translation as rice in coconut milk, popular in coastal towns like Mombasa, often served as a side with curries. While it may not stand out alone, it complements dishes like Kuku Paka or Samaki nicely.',
#     'type': 'summary_text'},
#    {'text': "**Including iconic dishes**\n\nI think it's a good idea to include Wali wa Nazi because, unlike regular rice, it's cooked in coconut milk on the coast, giving it a unique flavor. \n\nFor Mahamri, I’ll define it as “Swahili coconut and cardamom doughnuts,” noting that it’s similar to mandazi but distinct. They’re triangular sweet breads made with yeast, coconut milk, and cardamom, commonly enjoyed at breakfast with chai or mbaazi, emphasized by their wonderful flavor.\n\nKaimati, sweet dumplings popular during Ramadan, can be described as sugar-glazed or syrup-soaked, tying into the cultural significance.  \n\nFor an overview of Swahili cuisine, I’ll highlight its rich flavors influenced by trade, the use of coconut milk, typical spices, and key staples. I want to convey the blend of different cultural influences that define the cuisine.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca5051688191a60284cf080b6ea40fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://kenyalad.com/swahili-cuisine-in-kenya/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca5968a48191a4b03928a572bb2e0fb66a0de26da257',
#   'summary': [{'text': "**Creating Swahili Cuisine Overview**\n\nI'm considering crafting a brief overview that includes two or three sentences. One will cover the influences on Swahili cuisine, another will discuss key spices and ingredients, and maybe one about when it's typically eaten. Emphasizing that it's coastal is important, especially regarding seafood and coconut. Key ingredients like coconut milk, spices, seafood, rice, and tropical fruits should definitely be included. Next, I’ll focus on creating a list of popular Swahili dishes, possibly using bullet points or subheadings.",
#     'type': 'summary_text'},
#    {'text': '**Structuring Swahili Dishes List**\n\nThe user mentioned to include clear headers and descriptions with links under each dish. While I\'m unsure about making each dish a separate subheading, a bullet or numbered list could work well for a "List of Popular Dishes." I could structure it like this with short descriptions:  \n- **Pilau**: short description...  \n- **Biryani**: short description...  \n\nFor the next section, I can explain that I\'ll provide direct recipe links in a table format. I need to avoid duplicating content between the list and the table while ensuring each dish has enough detail.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca61fa00819183042817280894a80fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://www.the-star.co.ke/sasa/2024-02-21-rice-to-the-moment-your-ultimate-biryani-recipe'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca6d77b88191a3f9412003168c610fb66a0de26da257',
#   'summary': [{'text': '**Searching for recipes**\n\nI’ll probably skip the corporate link and stick with thefood.zone. The HelloMombasa content might point us to wanderlusttrails.africa for recipes, but it seems more like a cultural article than a recipe source. For our recipe list, I’m planning to include WeEatAtLast, which has Pilau, Wali wa Nazi, Kuku Paka, Samaki, and Mahamri. But Biryani isn’t on that site; I’ll need to double-check or see if Aroma of Zanzibar or another source has it.',
#     'type': 'summary_text'},
#    {'text': '**Exploring recipe sources**\n\nThefoodzone seems like it’ll work for us. I’m thinking about ToasterDing, which might have Mahamri since we noticed it before. If WeEatAtLast already covers Mahamri, we may not need it, but ToasterDing could provide multiple recipes, including potentially Biryani. It mentioned having "Authentic Mahamri," so I’ll look into that further to see if it offers anything else useful for our recipe collection.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca7351a48191b92b380eb79fe35c0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://toasterding.com/authentic-mahamri-recipe-with-cardamom/'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca7479b48191af2844ad1b81ab290fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca7549888191b408810fe38f6f450fb66a0de26da257',
#   'action': {'query': 'Kaimati recipe Kenyan blog', 'type': 'search'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca761bac819198bae345277b9a680fb66a0de26da257',
#   'summary': [{'text': '**Exploring recipes from Tuko and Gulf News**\n\nI\'m looking into a possible "Swahili kaimati recipe" from Tuko, which might be a new article, perhaps with a pumpkin spice twist. There\'s also a Gulf News article by Chef Faraja that could provide details since they seem to have a Pan-African recipe series. Chef Attalia\'s blog from 2008 offers some context but it\'s older. Given that Gulf News is a UAE site, but features a Kenyan chef, I think it’s worth exploring further.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca78cd68819193ae43b4858a5d5e0fb66a0de26da257',
#   'action': {'type': 'open_page',
#    'url': 'https://gulfnews.com/food/guide-cooking/pan-african-recipe-from-kenya-kaimati-or-fried-sweet-dumplings-1.1704449368795'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca78df4c8191b226cbfb6cedf4cc0fb66a0de26da257',
#   'summary': [],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca78e28c8191bd7d8e373b3b07120fb66a0de26da257',
#   'action': {'query': None,
#    'type': 'find_in_page',
#    'pattern': 'Method',
#    'url': 'https://gulfnews.com/food/guide-cooking/pan-african-recipe-from-kenya-kaimati-or-fried-sweet-dumplings-1.1704449368795'},
#   'status': 'completed',
#   'type': 'web_search_call'},
#  {'id': 'rs_687fca793ab0819196838229848ec12a0fb66a0de26da257',
#   'summary': [{'text': "**Considering recipe sources**\n\nThe Gulf News article likely has relevant information and quotes, but the formatting might make it hard to access easily. Time constraints might mean we can skip reading it since we already have adequate context. I noticed that Gulf News mentions treats popular as desserts or snacks, which we could cite. For the Kaimati recipe, linking to Tuko's step-by-step guide seems sensible, but I hope the article provides complete instructions since Tuko isn’t a dedicated recipe site. Alternatively, Gulf News might also provide the recipe steps.",
#     'type': 'summary_text'},
#    {'text': "**Considering recipe sources**\n\nGulf News might be region locked, which could limit access for some users, and I wonder if they require a login for full content. Alternatively, I found an older blog by Chef Attalia, but it might lack pictures. While Tuko is recognizable, it's often filled with ads and leans towards SEO-heavy content, which the user prefers to avoid. Meanwhile, Gulf News features a credible Kenyan chef, making it a strong source. I think I’ll include the Kaimati link from Gulf News while maintaining a balance with variety, though choosing between Kaimati and Mahamri could help streamline things.",
#     'type': 'summary_text'},
#    {'text': '**Deciding on recipe links**\n\nI’m listing our final dish names, starting with Pilau, which we have a link for: We Eat At Last. For Biryani, I’m leaning towards using thefood.zone’s Mombasa Biryani link because it fully loaded and has the complete recipe. However, I’m a bit concerned about its reputation since it looks like an aggregator and lacks clearly credited authors. I could also check MagicalKenya or HelloMombasa, but they focus on information, not recipes. Maybe I should search for "Mombasa biryani recipe blog Kenyan" to find more options.',
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'encrypted_content': None,
#   'status': None},
#  {'id': 'ws_687fca8500c08191b6f30cefe7009d060fb66a0de26da257',
# ...
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=Samaki%20wa%20kupaka%20is%20one,tilapia%20bathed%20in%20a%20rich'},
#      {'end_index': 6488,
#       'start_index': 6321,
#       'title': 'Samaki wa Kupaka- Grilled fish in Coconut Sauce - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/samaki-wa-kupaka-grilled-fish-in-coconut-sauce/#:~:text=refers%20to%20a%20marinade,grilled%20or%20cooked%2C%20in%20English'},
#      {'end_index': 6803,
#       'start_index': 6653,
#       'title': '10 Irresistible Swahili Local Dishes from Mombasa’s Streets',
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=Samaki%20wa%20kupaka%20is%20one,tilapia%20bathed%20in%20a%20rich'},
#      {'end_index': 7351,
#       'start_index': 7188,
#       'title': 'Swahili Coconut Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-coconut-rice/#:~:text=For%20those%20unfamiliar%2C%20Swahili%20coconut,including%20the%20island%20of%20Zanzibar'},
#      {'end_index': 7966,
#       'start_index': 7815,
#       'title': 'Swahili Coconut Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-coconut-rice/#:~:text=The%20use%20of%20coconut%20milk,these%20trade%20and%20migration%20activities'},
#      {'end_index': 8428,
#       'start_index': 8300,
#       'title': 'Mahamri Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/mahamri-recipe/#:~:text=Mahamri%20is%20a%20triangular,its%20own%2C%20as%20a%20snack'},
#      {'end_index': 8619,
#       'start_index': 8429,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=First%2C%20I%20introduce%20you%20to,made%20with%20self%20raising%20flour'},
#      {'end_index': 8961,
#       'start_index': 8833,
#       'title': 'Mahamri Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/mahamri-recipe/#:~:text=Mahamri%20is%20a%20triangular,its%20own%2C%20as%20a%20snack'},
#      {'end_index': 9164,
#       'start_index': 8962,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=Now%2C%20it%E2%80%99s%20time%20to%20share,of%20these%20flavoursome%20items%20already'},
#      {'end_index': 9629,
#       'start_index': 9443,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=it%20tastes%20so%20good%21%20The,hollow%20and%20plain%20in%20flavour'},
#      {'end_index': 10027,
#       'start_index': 9929,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text='},
#      {'end_index': 10160,
#       'start_index': 10028,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=,Spacing%20allows%20enough%20space'},
#      {'end_index': 10532,
#       'start_index': 10348,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=These%20sweet%20crusty%20dumplings%20are,popular%20Swahili%20snacks%20during%20Ramadan'},
#      {'end_index': 10887,
#       'start_index': 10703,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=These%20sweet%20crusty%20dumplings%20are,popular%20Swahili%20snacks%20during%20Ramadan'},
#      {'end_index': 11202,
#       'start_index': 11023,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=Moving%20on%20from%20the%20spicy,of%20item%20to%20be%20having'},
#      {'end_index': 12216,
#       'start_index': 12059,
#       'title': 'Swahili Kenyan Pilau Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/#:~:text=During%20my%20childhood%20in%20Kenya%2C,for%20celebrations%20of%20all%20kinds'},
#      {'end_index': 12634,
#       'start_index': 12485,
#       'title': '10 Irresistible Swahili Local Dishes from Mombasa’s Streets',
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=A%20true%20emblem%20of%20coastal,and%20history%20on%20a%20plate'},
#      {'end_index': 12993,
#       'start_index': 12886,
#       'title': 'East African Kuku Paka Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/#:~:text=what%20is%20kuku%20paka'},
#      {'end_index': 13157,
#       'start_index': 12994,
#       'title': 'East African Kuku Paka Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/#:~:text=It%20has%20Indian%2C%20Arabic%2C%20and,the%20Swahili%20culture%20is%20prevalent'},
#      {'end_index': 13599,
#       'start_index': 13449,
#       'title': '10 Irresistible Swahili Local Dishes from Mombasa’s Streets',
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=Samaki%20wa%20kupaka%20is%20one,tilapia%20bathed%20in%20a%20rich'},
#      {'end_index': 14059,
#       'start_index': 13896,
#       'title': 'Swahili Coconut Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-coconut-rice/#:~:text=For%20those%20unfamiliar%2C%20Swahili%20coconut,including%20the%20island%20of%20Zanzibar'},
#      {'end_index': 14437,
#       'start_index': 14309,
#       'title': 'Mahamri Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/mahamri-recipe/#:~:text=Mahamri%20is%20a%20triangular,its%20own%2C%20as%20a%20snack'},
#      {'end_index': 14850,
#       'start_index': 14666,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=These%20sweet%20crusty%20dumplings%20are,popular%20Swahili%20snacks%20during%20Ramadan'},
#      {'end_index': 15444,
#       'start_index': 15280,
#       'title': 'Exploring Swahili Cuisine: Best 10 Coastal Flavors to Savor - KenyaLad',
#       'type': 'url_citation',
#       'url': 'https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=Swahili%20food%20incorporates%20traditions%20from,to%20create%20distinct%20Swahili%20dishes'},
#      {'end_index': 15598,
#       'start_index': 15445,
#       'title': 'Exploring Swahili Cuisine: Best 10 Coastal Flavors to Savor - KenyaLad',
#       'type': 'url_citation',
#       'url': 'https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=Trade%20along%20the%20Swahili%20Coast,based%20foods%20across%20Swahili%20cuisine'},
#      {'end_index': 15986,
#       'start_index': 15810,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=Most%20Swahili%20dishes%20are%20characterised,you%20are%20hosting%20an%20event'},
#      {'end_index': 16171,
#       'start_index': 15987,
#       'title': 'Best Kenyan Swahili dishes - recipes for your pleasure! - Tuko.co.ke',
#       'type': 'url_citation',
#       'url': 'https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=These%20sweet%20crusty%20dumplings%20are,popular%20Swahili%20snacks%20during%20Ramadan'},
#      {'end_index': 16511,
#       'start_index': 16354,
#       'title': 'Swahili Kenyan Pilau Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-kenyan-pilau-rice/#:~:text=During%20my%20childhood%20in%20Kenya%2C,for%20celebrations%20of%20all%20kinds'},
#      {'end_index': 16789,
#       'start_index': 16682,
#       'title': 'East African Kuku Paka Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/#:~:text=what%20is%20kuku%20paka'},
#      {'end_index': 16953,
#       'start_index': 16790,
#       'title': 'East African Kuku Paka Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/east-african-kuku-paka-recipe/#:~:text=It%20has%20Indian%2C%20Arabic%2C%20and,the%20Swahili%20culture%20is%20prevalent'},
#      {'end_index': 17312,
#       'start_index': 17138,
#       'title': 'Samaki wa Kupaka- Grilled fish in Coconut Sauce - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/samaki-wa-kupaka-grilled-fish-in-coconut-sauce/#:~:text=a%20Swahili%20word%20that%20means,grilled%20or%20cooked%2C%20in%20English'},
#      {'end_index': 17655,
#       'start_index': 17492,
#       'title': 'Swahili Coconut Rice - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/swahili-coconut-rice/#:~:text=For%20those%20unfamiliar%2C%20Swahili%20coconut,including%20the%20island%20of%20Zanzibar'},
#      {'end_index': 17956,
#       'start_index': 17828,
#       'title': 'Mahamri Recipe - We Eat At Last',
#       'type': 'url_citation',
#       'url': 'https://weeatatlast.com/mahamri-recipe/#:~:text=Mahamri%20is%20a%20triangular,its%20own%2C%20as%20a%20snack'},
#      {'end_index': 18379,
#       'start_index': 18230,
#       'title': '10 Irresistible Swahili Local Dishes from Mombasa’s Streets',
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=A%20true%20emblem%20of%20coastal,and%20history%20on%20a%20plate'},
#      {'end_index': 18530,
#       'start_index': 18380,
#       'title': '10 Irresistible Swahili Local Dishes from Mombasa’s Streets',
#       'type': 'url_citation',
#       'url': 'https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=Samaki%20wa%20kupaka%20is%20one,tilapia%20bathed%20in%20a%20rich'},
#      {'end_index': 18928,
#       'start_index': 18739,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=First%2C%20I%20introduce%20you%20to,hollow%20and%20plain%20in%20flavour'},
#      {'end_index': 19131,
#       'start_index': 18929,
#       'title': 'Eat Like A True Local: Swahili Snacks That You Can Enjoy In Kenya | Trip101',
#       'type': 'url_citation',
#       'url': 'https://trip101.com/article/eat-like-a-true-local-swahili-snacks-that-you-can-enjoy-in-kenya#:~:text=Now%2C%20it%E2%80%99s%20time%20to%20share,of%20these%20flavoursome%20items%20already'},
#      {'end_index': 19500,
#       'start_index': 19321,
#       'title': 'Pan-African recipe from Kenya: Kaimati or fried sweet dumplings',
#       'type': 'url_citation',
#       'url': 'https://gulfnews.com/food/guide-cooking/pan-african-recipe-from-kenya-kaimati-or-fried-sweet-dumplings-1.1704449368795#:~:text=Pan,or%20fried%20sweet%20dumplings'}],
#     'text': '# Overview of Swahili Cuisine  \nSwahili cuisine refers to the traditional foods of the Swahili-speaking coastal regions of East Africa (primarily Kenya and Tanzania, including Zanzibar). It is a vibrant blend of African, Arab, Indian, and Persian culinary influences developed over centuries of Indian Ocean trade ([kenyalad.com](https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=Imagine%20a%20cuisine%20that%20captures,tradition%20with%20bold%2C%20unforgettable%20flavors)) ([kenyalad.com](https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=Swahili%20food%20incorporates%20traditions%20from,to%20create%20distinct%20Swahili%20dishes)). Key staple ingredients include rice, coconut milk, fresh seafood, tropical fruits, and a rich array of spices ([kenyalad.com](https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=As%20you%20explore%20Swahili%20cuisine%2C,coastal%20communities%20it%20comes%20from)). Dishes are often highly flavorful – common seasonings introduced by Arab traders include cloves (karafuu), cardamom, cinnamon, and ginger, while Indian influence brought curries, chapati flatbreads, and samosas ([kenyalad.com](https://kenyalad.com/swahili-cuisine-in-kenya/#:~:text=Swahili%20food%20incorporates%20traditions%20from,to%20create%20distinct%20Swahili%20dishes)). The generous use of spices, coconut, chili, and aromatics is a hallmark of Swahili cooking ([www.tuko.co.ke](https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=Most%20Swahili%20dishes%20are%20characterised,you%20are%20hosting%20an%20event)). Despite these exotic flavors, most Swahili dishes are home-friendly and do not require professional training to prepare ([www.tuko.co.ke](https://www.tuko.co.ke/271894-best-kenyan-swahili-dishes-recipes.html#:~:text=Most%20Swahili%20dishes%20are%20characterised,you%20are%20hosting%20an%20event)). Meals are typically enjoyed communally, reflecting the coastal culture’s emphasis on hospitality and shared tradition.\n\n# List of Popular Swahili Dishes  \nBelow are some beloved traditional Swahili dishes. These range from rice pilafs and curries to street snacks and sweet treats that are commonly enjoyed in Swahili homes. Each dish is briefly described with notes on its significance or typical serving context:\n\n- **Pilau** – A spiced rice pilaf cooked with meat (often beef, goat, or chicken) in a rich broth. Kenyan/Tanzanian *pilau* is characteristically brown in color from caramelized onions and meat, and seasoned with a fragrant blend like *pilau masala* (cloves, cumin, cardamom, etc.) ([weeatatlast.com](https://weeatatlast.com/swahili-kenyan-pilau-rice/#:~:text=Kenyan%20pilau%20draws%20influences%20from,the%20meat%20and%20frying%20onions)) ([weeatatlast.com](https://weeatatlast.com/swahili-kenyan-pilau-rice/#:~:text=ingredients)). Pilau is popularly served during special occasions and celebrations – it was traditionally reserved for weddings or holidays, and is still considered an essential dish at festive gatherings ([weeatatlast.com](https://weeatatlast.com/swahili-kenyan-pilau-rice/#:~:text=During%20my%20childhood%20in%20Kenya%2C,for%20celebrations%20of%20all%20kinds)).  \n\n- **Biryani** – A signature coastal rice dish that layers spiced meat and rice, reflecting Persian-Indian influence. Mombasa-style *biryani* is renowned for its rich flavor and aroma: tender chunks of chicken, beef, or goat are slow-cooked in a fragrant tomato-based curry and then layered with basmati rice ([hellomombasa.com](https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=A%20true%20emblem%20of%20coastal,and%20history%20on%20a%20plate)). The Swahili version tends to be moister (“wetter”) and more aromatic than Indian biryanis, often served with side condiments like *kachumbari* (a fresh tomato-onion salad) and a tangy tamarind chutney for contrast ([hellomombasa.com](https://hellomombasa.com/must-try-local-dishes-mombasa/#:~:text=A%20true%20emblem%20of%20coastal,and%20history%20on%20a%20plate ...
#     'type': 'output_text',
#     'logprobs': []}],
#   'role': 'assistant',
#   'status': 'completed',
#   'type': 'message'}]

# %%
import os
import re
import json
from openai import OpenAI

client = OpenAI()

system_message = """
You are a professional research assistant tasked with preparing a structured, data-driven report on the topic the user provides. Your goal is to deliver clear, factual, and well-cited analysis.

Do:
- Focus on data-rich insights: include specific figures, trends, statistics, and measurable outcomes (e.g., market size, historical trends, cost comparisons, adoption rates).
- When appropriate, summarize data in a way that could be turned into visualizations or tables (e.g., “this would work well as a bar chart comparing regional adoption rates”).
- Prioritize reliable, up-to-date sources: peer-reviewed research, government and international organizations, industry white papers, or credible journalism.
- Include inline citations and return all source metadata used in the report.

Be analytical, avoid vague statements, and ensure each section supports reasoned, evidence-backed conclusions that could inform decision-making or future research.
"""

# === Load prompts from file ===
input_path = "prompts/SESSION14-DR.txt"

def load_prompts(filepath, limit=10):
    with open(filepath, "r", encoding="utf-8") as f:
        text = f.read()

    pattern = r"Prompt\s+\d+:\s*(.*?)\s*(?=Prompt\s+\d+:|$)"
    matches = re.findall(pattern, text, re.DOTALL)
    return [prompt.strip() for prompt in matches[:limit]]

prompts = load_prompts(input_path, limit=10)
os.makedirs("deep_research_outputs", exist_ok=True)

# === Run research and save ===
for i, user_query in enumerate(prompts, start=1):
    output_path = f"deep_research_outputs/deep_topic_{i}.json"
    domain_path = f"deep_research_outputs/deep_topic_{i}_domains.json"

    if os.path.exists(output_path) and os.path.exists(domain_path):
        print(f"⏭️ Skipping prompt {i}: already exists.")
        continue

    print(f"🔍 Prompt {i}: {user_query[:80]}...")

    try:
        response = client.responses.create(
            model="o3-deep-research",
            input=[
                {
                    "role": "developer",
                    "content": [{"type": "input_text", "text": system_message}]
                },
                {
                    "role": "user",
                    "content": [{"type": "input_text", "text": user_query}]
                }
            ],
            reasoning={"summary": "auto"},
            tools=[
                {"type": "web_search_preview"},
                {"type": "code_interpreter", "container": {"type": "auto", "file_ids": []}}
            ]
        )
        response_data = response.model_dump()

        # === Save full output ===
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(response_data, f, indent=2, ensure_ascii=False)
        print(f"✅ Saved full response to {output_path}")

        # === Extract and save domains ===
        domains = set()
        steps = response_data.get("output", [])

        for step in steps:
            action = step.get("action", {})
            if (
                step.get("type") == "web_search_call"
                and isinstance(action, dict)
                and "url" in action
            ):
                url = action["url"]
                if isinstance(url, str):
                    domain = urlparse(url).netloc
                    if domain:
                        domains.add(domain)

        with open(domain_path, "w", encoding="utf-8") as f:
            json.dump(list(domains), f, indent=2, ensure_ascii=False)
        print(f"🌐 Saved {len(domains)} unique domains to {domain_path}")

    except Exception as e:
        print(f"❌ Error on prompt {i}: {e}")
# Out:
# ⏭️ Skipping prompt 1: already exists.
# 🔍 Prompt 2: Instructions for Researcher
#
# Objective:
# I want to gather detailed information ...
# ❌ Error on prompt 2: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# ⏭️ Skipping prompt 3: already exists.
# 🔍 Prompt 4: Instructions for Researcher:
# **Goal:**
# Please gather comprehensive and actio...
# ❌ Error on prompt 4: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# ⏭️ Skipping prompt 5: already exists.
# ⏭️ Skipping prompt 6: already exists.
# ⏭️ Skipping prompt 7: already exists.
# ⏭️ Skipping prompt 8: already exists.
# ⏭️ Skipping prompt 9: already exists.
# ⏭️ Skipping prompt 10: already exists.

# %%
# system_message = """
# You are a professional researcher preparing a structured, data-driven report on behalf of a global health economics team. Your task is to analyze the health question the user poses.

# Do:
# - Focus on data-rich insights: include specific figures, trends, statistics, and measurable outcomes (e.g., reduction in hospitalization costs, market size, pricing trends, payer adoption).
# - When appropriate, summarize data in a way that could be turned into charts or tables, and call this out in the response (e.g., “this would work well as a bar chart comparing per-patient costs across regions”).
# - Prioritize reliable, up-to-date sources: peer-reviewed research, health organizations (e.g., WHO, CDC), regulatory agencies, or pharmaceutical earnings reports.
# - Include inline citations and return all source metadata.

# Be analytical, avoid generalities, and ensure that each section supports data-backed reasoning that could inform healthcare policy or financial modeling.
# """

# import os
# import re
# import json

# def parse_instruction_prompts(input_path):
#     with open(input_path, "r", encoding="utf-8") as f:
#         content = f.read()

#     # Match everything from "Prompt N:" to the next "Prompt M:" or end of file
#     prompt_blocks = re.findall(r"Prompt\s+\d+:\s*(.*?)(?=\nPrompt\s+\d+:|$)", content, re.DOTALL)

#     # Strip and return the list of full prompts
#     return [block.strip() for block in prompt_blocks]

# input_path = "rewritten_prompts/SESSION14-DR.txt"  
# output_path = "deep_research_session_batch_requests.jsonl"

# prompts = parse_instruction_prompts(input_path)

# # === Generate JSONL for batch submission ===
# with open(output_path, "w", encoding="utf-8") as out_f:
#     for task_id, prompt in enumerate(prompts, start=1):
#         request = {
#             "custom_id": f"task-{task_id}",
#             "method": "POST",
#             "url": "/v1/responses",
#             "body": {
#                 "model": "o3-deep-research",
#                 "input": [
#                     {
#                         "role": "developer",
#                         "content": [{"type": "input_text", "text": system_message}]
#                     },
#                     {
#                         "role": "user",
#                         "content": [{"type": "input_text", "text": prompt}]
#                     }
#                 ],
#                 "reasoning": {"summary": "auto"},
#                 "tools": [
#                     {"type": "web_search_preview"},
#                     {
#                         "type": "code_interpreter",
#                         "container": {"type": "auto", "file_ids": []}
#                     }
#                 ]
#             }
#         }
#         out_f.write(json.dumps(request) + "\n")

# print(f"✅ Created batch request file with {len(prompts)} prompts: {output_path}")
# Out:
# ✅ Created batch request file with 60 prompts: deep_research_session_batch_requests.jsonl
